# %% [markdown]
# ##### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
data=pd.read_csv("..\Dataset\Final dataset.csv")
data.head()
# Out:
#   Emission_date Expiration_date  CO2_emission Emission_classification  \
# 0    2013-06-29      2023-06-29         30.11                       E
# 1    2013-09-26      2023-09-26         46.06                       E
# 2    2014-02-26      2024-02-26         20.30                       D
# 3    2013-06-12      2023-06-12         39.21                       E
# 4    2013-06-27      2023-06-27        103.75                       G
#
#    Consumption_KWh_per_m2_per_year Consumption_classification  \
# 0                           142.33                          E
# 1                           174.42                          E
# 2                            94.16                          D
# 3                           187.66                          E
# 4                           409.03                          G
#
#          Building_type Building_condition  Year_of_construction  \
# 0  Vivienda individual          Existente                  1962
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161275 entries, 0 to 161274
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Emission_date                    161275 non-null  object
#  1   Expiration_date                  161275 non-null  object
#  2   CO2_emission                     161275 non-null  float64
#  3   Emission_classification          161275 non-null  object
#  4   Consumption_KWh_per_m2_per_year  161275 non-null  float64
#  5   Consumption_classification       161275 non-null  object
#  6   Building_type                    161275 non-null  object
#  7   Building_condition               161275 non-null  object
#  8   Year_of_construction             161275 non-null  int64
#  9   Surface_area_m2                  161275 non-null  float64
#  10  Municipality                     161275 non-null  object
# ...

# %% [markdown]
# ##### Data Cleaning

# %%
data.duplicated().sum()
# Out:
# np.int64(2799)

# %%
data.drop_duplicates()
# Out:
#               Emission_date Expiration_date  CO2_emission  \
# 0                2013-06-29      2023-06-29         30.11
# 1                2013-09-26      2023-09-26         46.06
# 2                2014-02-26      2024-02-26         20.30
# 3                2013-06-12      2023-06-12         39.21
# 4                2013-06-27      2023-06-27        103.75
# ...                     ...             ...           ...
# 161269  2023-12-26 00:00:00      2028-12-26        179.85
# 161271  2023-11-24 00:00:00      2033-12-20         18.68
# 161272  2023-12-22 00:00:00      2033-12-22         42.27
# 161273  2023-12-23 00:00:00      2033-12-23         40.00
# 161274  2023-12-27 00:00:00      2028-12-27        118.27
#
#        Emission_classification  Consumption_KWh_per_m2_per_year  \
# 0                            E                           142.33
# 1                            E                           174.42
# 2                            D                            94.16
# ...

# %% [markdown]
# #### Converting into date format

# %%
def convert_to_dateform(df,column):
   df[column] = pd.to_datetime(df[column] ,errors='coerce')

# %%
dates=['Expiration_date','Date']

for i in dates:
   convert_to_dateform(data,i)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161275 entries, 0 to 161274
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Emission_date                    161275 non-null  object
#  1   Expiration_date                  161275 non-null  datetime64[ns]
#  2   CO2_emission                     161275 non-null  float64
#  3   Emission_classification          161275 non-null  object
#  4   Consumption_KWh_per_m2_per_year  161275 non-null  float64
#  5   Consumption_classification       161275 non-null  object
#  6   Building_type                    161275 non-null  object
#  7   Building_condition               161275 non-null  object
#  8   Year_of_construction             161275 non-null  int64
#  9   Surface_area_m2                  161275 non-null  float64
#  10  Municipality                     161275 non-null  object
# ...

# %% [markdown]
# #### Converting Month column to numeric

# %%
data['month']=pd.to_numeric(data['month'])

# %%
print("Row :",data.shape[0])
print("Columns :",data.shape[1])
print("\nFeatures :\n",data.columns.to_list())
print("\nMissing Values :\n",data.isna().any())
# Out:
# Row : 161275
# Columns : 27
#
# Features :
#  ['Emission_date', 'Expiration_date', 'CO2_emission', 'Emission_classification', 'Consumption_KWh_per_m2_per_year', 'Consumption_classification', 'Building_type', 'Building_condition', 'Year_of_construction', 'Surface_area_m2', 'Municipality', 'Province', 'GPS_coordinates', 'Days_until_expiration', 'year', 'month', 'day', 'Date', 'Earth Skin Temperature', ' Humidity', 'Surface Pressure', 'Temperature at 2 Meters Range', 'Temperature at 2 Meters Minimum', 'Temperature at 2 Meters Maximum', 'Wind Speed', 'Name', 'holidays']
#
# Missing Values :
#  Emission_date                      False
# Expiration_date                    False
# CO2_emission                       False
# Emission_classification            False
# Consumption_KWh_per_m2_per_year    False
# Consumption_classification         False
# Building_type                      False
# Building_condition                 False
# Year_of_construction               False
# ...

# %%
print("\nUnique Values :\n",data.nunique())
# Out:
# Unique Values :
#  Emission_date                       8966
# Expiration_date                     3913
# CO2_emission                       14672
# Emission_classification                7
# Consumption_KWh_per_m2_per_year    43446
# Consumption_classification             8
# Building_type                          5
# Building_condition                     4
# Year_of_construction                 216
# Surface_area_m2                    19540
# Municipality                         713
# Province                               3
# GPS_coordinates                    48945
# Days_until_expiration               3513
# year                                  11
# month                                 12
# day                                   31
# Date                                3913
# Earth Skin Temperature              2140
#  Humidity                            186
# Surface Pressure                     370
# Temperature at 2 Meters Range       1315
# ...

# %%
data.describe()
# Out:
#                      Expiration_date   CO2_emission  \
# count                         161275  161275.000000
# mean   2028-08-24 22:07:34.612307968      55.321134
# min              2023-01-01 00:00:00       0.000000
# 25%              2025-12-21 00:00:00      37.500000
# 50%              2028-05-23 00:00:00      50.400000
# 75%              2031-06-11 00:00:00      66.730000
# max              2033-12-27 00:00:00     299.420000
# std                              NaN      28.238332
#
#        Consumption_KWh_per_m2_per_year  Year_of_construction  Surface_area_m2  \
# count                    161275.000000         161275.000000    161275.000000
# mean                        276.252739           1976.887608       169.106361
# min                           0.000000             50.000000         0.000000
# 25%                         179.240000           1964.000000        59.875000
# 50%                         239.860000           1977.000000        76.510000
# ...

# %%
data_non_indexed=data.copy()

# %%
data=data.set_index('Date')

# %%
data.index
# Out:
# DatetimeIndex(['2013-06-29', '2013-09-26', '2014-02-26', '2013-06-12',
#                '2013-06-27', '2013-06-17', '2014-02-13', '2014-04-08',
#                '2014-04-07', '2013-12-16',
#                ...
#                '2023-12-20', '2013-08-06', '2023-12-22', '2023-12-19',
#                '2023-12-26', '2023-12-26', '2023-11-24', '2023-12-22',
#                '2023-12-23', '2023-12-27'],
#               dtype='datetime64[ns]', name='Date', length=161275, freq=None)

# %%
data.head()
# Out:
#            Emission_date Expiration_date  CO2_emission  \
# Date
# 2013-06-29    2013-06-29      2023-06-29         30.11
# 2013-09-26    2013-09-26      2023-09-26         46.06
# 2014-02-26    2014-02-26      2024-02-26         20.30
# 2013-06-12    2013-06-12      2023-06-12         39.21
# 2013-06-27    2013-06-27      2023-06-27        103.75
#
#            Emission_classification  Consumption_KWh_per_m2_per_year  \
# Date
# 2013-06-29                       E                           142.33
# 2013-09-26                       E                           174.42
# 2014-02-26                       D                            94.16
# 2013-06-12                       E                           187.66
# 2013-06-27                       G                           409.03
#
#            Consumption_classification        Building_type Building_condition  \
# Date
# 2013-06-29                          E  Vivienda individual          Existente
# ...

# %%
print(data.index.is_monotonic_increasing)
# Out:
# False

# %%
data = data.sort_index()

# %%
print(data.index.min())
print(data.index.max())
# Out:
# 2013-01-01 00:00:00
# 2023-12-27 00:00:00

# %%
data.loc['2013':'2015']
# Out:
#            Emission_date Expiration_date  CO2_emission  \
# Date
# 2013-01-01    2013-01-01      2023-01-01         22.04
# 2013-01-01    2013-01-01      2023-01-01        140.14
# 2013-01-01    2013-01-01      2023-01-01         26.10
# 2013-01-01    2013-01-01      2023-01-01         60.48
# 2013-01-02    2013-01-02      2023-01-02         18.56
# ...                  ...             ...           ...
# 2015-12-31    2015-12-31      2025-12-31         51.43
# 2015-12-31    2015-12-31      2025-12-31         62.30
# 2015-12-31    2015-12-31      2025-12-31         68.02
# 2015-12-31    2015-12-31      2025-12-31         22.79
# 2015-12-31    2015-12-31      2025-12-31        100.81
#
#            Emission_classification  Consumption_KWh_per_m2_per_year  \
# Date
# 2013-01-01                       D                           106.85
# 2013-01-01                       G                           535.52
# 2013-01-01                       D                           117.59
# ...

# %%
consumption_data=data['Consumption_KWh_per_m2_per_year']
consumption_data.head()
# Out:
# Date
# 2013-01-01    106.85
# 2013-01-01    535.52
# 2013-01-01    117.59
# 2013-01-01    267.21
# 2013-01-02     87.76
# Name: Consumption_KWh_per_m2_per_year, dtype: float64
